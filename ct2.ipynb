# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/A"
# Out:
# /content/drive/MyDrive/A

# %%
# %%capture
# !pip3 install tensorflow
# !pip3 install nibabel
# !pip3 install scipy
# !pip3 install -r requirements.txt
# !pip3 install torchio

# %%
import os
import time
import zipfile
import numpy as np
import nibabel as nib
from tensorflow import keras
from scipy import ndimage

from torch.optim import Adam
from torch import nn
import generate_model
import models.EfficientNet
import torch
from torch.utils.data import DataLoader
import torchio as tio

# %matplotlib notebook
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Download url of normal CT scans and abnormal scans.

if not os.path.exists("CT-0.zip"):
  url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-0.zip"
  filename = os.path.join(os.getcwd(), "CT-0.zip")
  keras.utils.get_file(filename, url)


if not os.path.exists("CT-23.zip"):
  url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-23.zip"
  filename = os.path.join(os.getcwd(), "CT-23.zip")
  keras.utils.get_file(filename, url)


if not os.path.exists("./CTData"):
    os.makedirs("CTData")

    with zipfile.ZipFile("CT-0.zip", "r") as z_fp:
        z_fp.extractall("./CTData/")

    with zipfile.ZipFile("CT-23.zip", "r") as z_fp:
        z_fp.extractall("./CTData/")


normal_scan_paths = [
    (os.path.join(os.getcwd(), "CTData/CT-0", x), 0)
    for x in os.listdir("CTData/CT-0")
]

abnormal_scan_paths = [
    (os.path.join(os.getcwd(), "CTData/CT-23", x), 1)
    for x in os.listdir("CTData/CT-23")
]

print("CT scans with normal lung tissue: " + str(len(normal_scan_paths)))
print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))
# Out:
# CT scans with normal lung tissue: 100
# CT scans with abnormal lung tissue: 100

# %%
# both dataset should have equal samples.

split = 0.7

permutation = np.random.permutation(range(len(normal_scan_paths)))
train = permutation[:int(len(normal_scan_paths) * split)]
val = permutation[int(len(normal_scan_paths) * split):]

train_subjects = []
for i in train:
  subject_path_n, label_n = normal_scan_paths[i]
  subject_path_a, label_a = abnormal_scan_paths[i]

  subject_n = tio.Subject(t1 = tio.ScalarImage(subject_path_n), label = label_n)
  subject_a = tio.Subject(t1 = tio.ScalarImage(subject_path_a), label = label_a)

  train_subjects.append(subject_n)
  train_subjects.append(subject_a)



val_subjects = []
for i in val:
  subject_path_n, label_n = normal_scan_paths[i]
  subject_path_a, label_a = abnormal_scan_paths[i]

  subject_n = tio.Subject(t1 = tio.ScalarImage(subject_path_n), label = label_n)
  subject_a = tio.Subject(t1 = tio.ScalarImage(subject_path_a), label = label_a)

  val_subjects.append(subject_n)
  val_subjects.append(subject_a)

# %%
normalize = tio.RescaleIntensity(out_min_max = (0, 1), in_min_max = (-1000, 400))
resize = tio.Resize((128, 128, 64))
affine = tio.OneOf({tio.RandomAffine(): 0.8 })

train_transform = tio.Compose([normalize, resize, affine])
val_transform = tio.Compose([normalize, resize])

train_subjects_dataset = tio.SubjectsDataset(train_subjects, transform=train_transform)
val_subjects_dataset = tio.SubjectsDataset(val_subjects, transform=val_transform)

training_loader = DataLoader(train_subjects_dataset, shuffle=True, batch_size=4)
validation_loader = DataLoader(val_subjects_dataset, batch_size=4)

train_steps = len(training_loader.dataset) // 4
val_steps = len(validation_loader.dataset) // 4

# %%
def train_model(epoch, model, device, lossFn, optimizer, history, mute = True):
	print("[INFO] training the network...")
	startTime = time.time()
	history["train_loss"] = []
	history["train_acc"] = []
	history["val_loss"] = []
	history["val_acc"] = []
	for e in range(0, epoch):
		model.train()
		totalTrainLoss = 0
		totalValLoss = 0
		trainCorrect = 0
		valCorrect = 0
		for subjects_batch in training_loader:
			x = subjects_batch['t1'][tio.DATA].to(device)
			y = subjects_batch['label'].to(device)
			optimizer.zero_grad()
			pred = model(x)
			loss = lossFn(pred, y)
			loss.backward()
			optimizer.step()
			totalTrainLoss += loss
			trainCorrect += (pred.argmax(1) == y).type(torch.float).sum().item()

		with torch.no_grad():
			model.eval()
			for subjects_batch in validation_loader:
				x = subjects_batch['t1'][tio.DATA].to(device)
				y = subjects_batch['label'].to(device)
				pred = model(x)
				totalValLoss += lossFn(pred, y)
				valCorrect += (pred.argmax(1) == y).type(torch.float).sum().item()

		avgTrainLoss = totalTrainLoss / train_steps
		avgValLoss = totalValLoss / val_steps
		trainCorrect = trainCorrect / len(training_loader.dataset)
		valCorrect = valCorrect / len(validation_loader.dataset)
		history["train_loss"].append(avgTrainLoss.cpu().detach().numpy())
		history["train_acc"].append(trainCorrect)
		history["val_loss"].append(avgValLoss.cpu().detach().numpy())
		history["val_acc"].append(valCorrect)
		if not mute:
			print("[INFO] EPOCH: {}/{}".format(e + 1, epoch))
			print("Train loss: {:.6f}, Train accuracy: {:.4f}".format(
				avgTrainLoss, trainCorrect))
			print("Val loss: {:.6f}, Val accuracy: {:.4f}\n".format(
				avgValLoss, valCorrect))
	print("[INFO] total time taken to train the model: {}s".format(
		round(time.time() - startTime, 2)))

def plot_history(history):
	fig, ax = plt.subplots(1, 2, figsize=(20, 3))
	ax = ax.ravel()
	for i, metric in enumerate(["acc", "loss"]):
			ax[i].plot(history["train_" + metric])
			ax[i].plot(history["val_" + metric])
			ax[i].set_title("Model {}".format(metric))
			ax[i].set_xlabel("epochs")
			ax[i].set_ylabel(metric)
			ax[i].legend(["train", "val"])

# %%
# EfficientNet b0
model = models.EfficientNet.EfficientNet3D.from_name(
            'efficientnet-b0', 
            override_params={'num_classes': 2}, 
            in_channels=1).cuda()
lossFn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr = 10e-4, weight_decay = 10e-5)
history_0 = {}

train_model(200, model, device, lossFn, optimizer, history_0, mute = False)
plot_history(history_0)
# Out:
# [INFO] training the network...
# [INFO] EPOCH: 1/200
# Train loss: 0.875454, Train accuracy: 0.5071
# Val loss: 0.693485, Val accuracy: 0.5000
#
# [INFO] EPOCH: 2/200
# Train loss: 0.800749, Train accuracy: 0.4214
# Val loss: 0.694800, Val accuracy: 0.5000
#
# [INFO] EPOCH: 3/200
# Train loss: 0.727618, Train accuracy: 0.5429
# Val loss: 0.693163, Val accuracy: 0.5000
#
# [INFO] EPOCH: 4/200
# Train loss: 0.760523, Train accuracy: 0.4071
# Val loss: 0.699752, Val accuracy: 0.5000
#
# [INFO] EPOCH: 5/200
# Train loss: 0.736830, Train accuracy: 0.4714
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH:
# Val loss: 0.693160, Val accuracy: 0.5000
#
# [INFO] EPOCH: 27/200
# Train loss: 0.693339, Train accuracy: 0.5000
# Val loss: 0.693168, Val accuracy: 0.5000
#
# [INFO] EPOCH: 28/200
# Train loss: 0.693294, Train accuracy: 0.5000
# Val loss: 0.693163, Val accuracy: 0.5000
#
# [INFO] EPOCH: 29/200
# Train loss: 0.693272, Train accuracy: 0.5000
# Val loss: 0.693160, Val accuracy: 0.5000
#
# [INFO] EPOCH: 30/200
# Train loss: 0.693420, Train accuracy: 0.5000
# Val loss: 0.693153, Val accuracy: 0.5000
#
# [INFO] EPOCH: 31/200
# Train loss: 0.693346, Train accuracy: 0.5000
# Val loss: 0.693151, Val accuracy: 0.5000
#
# [INFO] EPOCH: 32/200
# Train loss: 0.693336, Train accuracy: 0.4857
# Val loss: 0.693148, Val accuracy: 0.5000
#
# [INFO] EPOCH: 33/200
# Train loss: 0.693263, Train accuracy: 0.5000
# Val loss: 0.693156, Val accuracy: 0.5000
#
# [INFO] EPOCH: 34/200
# Train loss: 0.693283, Train accuracy: 0.5000
# Val loss: 0.693161, Val accuracy: 0.5000
#
# [INFO] EPOCH: 35/200
# Train loss: 0.693533, Train accuracy: 0.5000
# Val loss: 0.693163, Val accuracy: 0.5000
#
# [INFO] EPOCH: 36/200
# Train loss: 0.693249, Train accuracy: 0.5000
# Val loss: 0.693152, Val accuracy: 0.5000
#
# [INFO] EPOCH: 37/200
# Train loss: 0.693486, Train accuracy: 0.4071
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH: 38/200
# Train loss: 0.693575, Train accuracy: 0.5000
# Val loss: 0.693163, Val accuracy: 0.5000
#
# [INFO] EPOCH: 39/200
# Train loss: 0.693257, Train accuracy: 0.5000
# Val loss: 0.693159, Val accuracy: 0.5000
#
# [INFO] EPOCH: 40/200
# Train loss: 0.693249, Train accuracy: 0.5000
# Val loss: 0.693150, Val accuracy: 0.5000
#
# [INFO] EPOCH: 41/200
# Train loss: 0.693304, Train accuracy: 0.4214
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH: 42/200
# Train loss: 0.693195, Train accuracy: 0.5000
# Val loss: 0.693150, Val accuracy: 0.5000
#
# [INFO] EPOCH: 43/200
# Train loss: 0.693330, Train accuracy: 0.4429
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH: 44/200
# Train loss: 0.693297, Train accuracy: 0.4214
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH: 45/200
# Train loss: 0.693215, Train accuracy: 0.5000
# Val loss: 0.693149, Val accuracy: 0.5000
#
# [INFO] EPOCH: 46/200
# Train loss: 0.693322, Train accuracy: 0.5000
# Val loss: 0.693153, Val accuracy: 0.5000
#
# [INFO] EPOCH: 47/200
# Train loss: 0.693228, Train accuracy: 0.5000
# Val loss: 0.693151, Val accuracy: 0.5000
#
# [INFO] EPOCH: 48/200
# Train loss: 0.693306, Train accuracy: 0.4571
# Val loss: 0.693148, Val accuracy: 0.5000
#
# [INFO] EPOCH: 49/200
# Train loss: 0.693246, Train accuracy: 0.4429
# Val loss: 0.693147, Val accuracy: 0.5000
#
# [INFO] EPOCH: 50/200
# Train loss: 0.693331, Train accuracy: 0.4857
# Val loss: 0.693152, Val accuracy: 0.5000
#
# [INFO] EPOCH: 51/200
# Train loss: 0.693609, Train accuracy: 0.4714
# Val loss: 0.693151, Val accuracy: 0.5000
#
# [INFO] EPOCH: 52/200
# Train loss: 0.693230, Train accuracy: 0.5000
# Val loss: 0.693148, Val accuracy: 0.5000
#
# [INFO] EPOCH: 53/200
# Train loss: 0.693278, Train accuracy: 0.4857
# Val loss: 0.693149, Val accuracy: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3ef09fac2b31> in <cell line: 10>()
#       8 history_1 = {}
#       9
# ---> 10 train_model(200, model, device, lossFn, optimizer, history_1, mute = False)
#      11 plot_history(history_1)
#
# <ipython-input-8-5932a2608526> in train_model(epoch, model, device, lossFn, optimizer, history, mute)
#      12                 trainCorrect = 0
#      13                 valCorrect = 0
# ---> 14                 for subjects_batch in training_loader:
#      15                         x = subjects_batch['t1'][tio.DATA].to(device)
#      16                         y = subjects_batch['label'].to(device)
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     632                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633                 self._reset()  # type: ignore[call-arg]
# --> 634             data = self._next_data()
#     635             self._num_yielded += 1
#     636             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     676     def _next_data(self):
#     677         index = self._next_index()  # may raise StopIteration
# --> 678         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679         if self._pin_memory:
#     680             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.9/dist-packages/torchio/data/dataset.py in __getitem__(self, index)
#      97         # Apply transform (this is usually the bottleneck)
#      98         if self._transform is not None:
# ---> 99             subject = self._transform(subject)
#     100         return subject
#     101
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/transform.py in __call__(self, data)
#     156             subject = copy.copy(subject)
#     157         with np.errstate(all='raise', under='ignore'):
# --> 158             transformed = self.apply_transform(subject)
#     159         if self.keep is not None:
#     160             for name, image in images_to_keep.items():
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/augmentation/composition.py in apply_transform(self, subject)
#      49     def apply_transform(self, subject: Subject) -> Subject:
#      50         for transform in self.transforms:
# ---> 51             subject = transform(subject)  # type: ignore[assignment]
#      52         return subject
#      53
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/transform.py in __call__(self, data)
#     156             subject = copy.copy(subject)
#     157         with np.errstate(all='raise', under='ignore'):
# --> 158             transformed = self.apply_transform(subject)
#     159         if self.keep is not None:
#     160             for name, image in images_to_keep.items():
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/augmentation/composition.py in apply_transform(self, subject)
#     115         transforms = list(self.transforms_dict.keys())
#     116         transform = transforms[index]
# --> 117         transformed = transform(subject)
#     118         return transformed  # type: ignore[return-value]
#     119
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/transform.py in __call__(self, data)
#     156             subject = copy.copy(subject)
#     157         with np.errstate(all='raise', under='ignore'):
# --> 158             transformed = self.apply_transform(subject)
#     159         if self.keep is not None:
#     160             for name, image in images_to_keep.items():
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/augmentation/spatial/random_affine.py in apply_transform(self, subject)
#     177         }
#     178         transform = Affine(**self.add_include_exclude(arguments))
# --> 179         transformed = transform(subject)
#     180         assert isinstance(transformed, Subject)
#     181         return transformed
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/transform.py in __call__(self, data)
#     156             subject = copy.copy(subject)
#     157         with np.errstate(all='raise', under='ignore'):
# --> 158             transformed = self.apply_transform(subject)
#     159         if self.keep is not None:
#     160             for name, image in images_to_keep.items():
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/augmentation/spatial/random_affine.py in apply_transform(self, subject)
#     383                         assert isinstance(self.default_pad_value, Number)
#     384                         default_value = float(self.default_pad_value)
# --> 385                 transformed_tensor = self.apply_affine_transform(
#     386                     sitk_image,
#     387                     transform,
#
# /usr/local/lib/python3.9/dist-packages/torchio/transforms/augmentation/spatial/random_affine.py in apply_affine_transform(self, sitk_image, transform, interpolation, default_value)
#     408         resampler.SetOutputPixelType(sitk.sitkFloat32)
#     409         resampler.SetTransform(transform)
# --> 410         resampled = resampler.Execute(floating)
#     411
#     412         np_array = sitk.GetArrayFromImage(resampled)
#
# /usr/local/lib/python3.9/dist-packages/SimpleITK/SimpleITK.py in Execute(self, image1)
#   49590
#   49591         """
# > 49592         return _SimpleITK.ResampleImageFilter_Execute(self, image1)
#   49593
#   49594     def SetReferenceImage(self, refImage):
#
# KeyboardInterrupt:

# %%
# EfficientNet b0
model = models.EfficientNet.EfficientNet3D.from_name(
            'efficientnet-b0', 
            override_params={'num_classes': 2}, 
            in_channels=1).cuda()
lossFn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr = 10e-4, weight_decay = 5 * 10e-3)
history_2 = {}

train_model(200, model, device, lossFn, optimizer, history_2, mute = False)
plot_history(history_2)
# Out:
# [INFO] training the network...
# [INFO] EPOCH: 1/200
# Train loss: 0.843385, Train accuracy: 0.5357
# Val loss: 0.693164, Val accuracy: 0.5000
#
# [INFO] EPOCH: 2/200
# Train loss: 0.858637, Train accuracy: 0.4571
